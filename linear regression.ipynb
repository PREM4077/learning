# %%
import warnings
warnings.simplefilter('ignore')

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
f=pd.read_csv("C:/Users/ADMIN/Downloads/Admission_Predict_Ver1.1 (1).csv")
f
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
F=f.drop(['Serial No.','GRE Score','TOEFL Score','University Rating','LOR','SOP','Research',],axis=1)

# %%
F.head()
# Out:
#    CGPA  Chance of Admit
# 0  9.65              0.92
# 1  8.87              0.76
# 2  8.00              0.72
# 3  8.67              0.80
# 4  8.21              0.65

# %%
a=F.iloc[:,0].values.reshape(-1,1)
b=F.iloc[:,1].values.reshape(-1,1)

# %%
a
# Out:
# array([[9.65],
#        [8.87],
#        [8.  ],
#        [8.67],
#        [8.21],
#        [9.34],
#        [8.2 ],
#        [7.9 ],
#        [8.  ],
#        [8.6 ],
#        [8.4 ],
#        [9.  ],
#        [9.1 ],
#        [8.  ],
#        [8.2 ],
#        [8.3 ],
#        [8.7 ],
#        [8.  ],
#        [8.8 ],
#        [8.5 ],
#        [7.9 ],
#        [8.4 ],
#        [9.5 ],
#        [9.7 ],
#        [9.8 ],
#        [9.6 ],
#        [8.8 ],
#        [7.5 ],
#        [7.2 ],
#        [7.3 ],
#        [8.1 ],
#        [8.3 ],
#        [9.4 ],
#        [9.6 ],
#        [9.8 ],
#        [9.2 ],
#        [8.4 ],
#        [7.8 ],
#        [7.5 ],
#        [7.7 ],
#        [8.  ],
#        [8.2 ],
#        [8.5 ],
#        [9.1 ],
#        [9.4 ],
#        [9.1 ],
#        [9.3 ],
#        [9.7 ],
#        [8.85],
#        [8.4 ],
#        [8.3 ],
#        [7.9 ],
#        [8.  ],
#        [8.1 ],
#        [8.  ],
#        [7.7 ],
#        [7.4 ],
#        [7.6 ],
# ...

# %%
b
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(a,b)
pt.title('PREM')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
A_train,A_text,B_train,B_text=train_test_split(a,b,train_size=0.10,random_state=0)

# %%
A_train.shape
# Out:
# (50, 1)

# %%
A_text.shape
# Out:
# (450, 1)

# %%
B_text.shape
# Out:
# (450, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(A_train,B_train)
# Out:
# LinearRegression()

# %%
b_predict=lm.predict(B_text)

# %%
b_predict
# Out:
# array([[-0.88322469],
#        [-0.84093336],
#        [-0.85100272],
#        [-0.82885012],
#        [-0.8751692 ],
#        [-0.90336342],
#        [-0.90336342],
#        [-0.88121082],
#        [-0.90739117],
#        [-0.8530166 ],
#        [-0.88121082],
#        [-0.86308596],
#        [-0.88322469],
#        [-0.8530166 ],
#        [-0.83287787],
#        [-0.92551603],
#        [-0.84898885],
#        [-0.86509983],
#        [-0.85100272],
#        [-0.89530793],
#        [-0.8973218 ],
#        [-0.86308596],
#        [-0.89128019],
#        [-0.82482237],
#        [-0.83489174],
#        [-0.87718307],
#        [-0.87114145],
#        [-0.8973218 ],
#        [-0.91544666],
#        [-0.88322469],
#        [-0.87315533],
#        [-0.91746054],
#        [-0.8973218 ],
#        [-0.83690561],
#        [-0.93357152],
#        [-0.9053773 ],
#        [-0.84294723],
#        [-0.83287787],
#        [-0.88523857],
#        [-0.87114145],
#        [-0.86711371],
# ...

# %%
comp=pd.DataFrame(A_text,columns=['B'])

# %%
comp.head()
# Out:
#       B
# 0  7.92
# 1  9.12
# 2  8.90
# 3  9.08
# 4  8.13

# %%
Comp=pd.DataFrame(B_text,columns=['A'])

# %%
Comp
# Out:
#         A
# 0    0.64
# 1    0.85
# 2    0.80
# 3    0.91
# 4    0.68
# ..    ...
# 445  0.97
# 446  0.74
# 447  0.91
# 448  0.78
# 449  0.89
#
# [450 rows x 1 columns]

# %%
Comp['score']=A_text

# %%
Comp
# Out:
#         A       avl  score
# 0    0.64 -0.883225   7.92
# 1    0.85 -0.840933   9.12
# 2    0.80 -0.851003   8.90
# 3    0.91 -0.828850   9.08
# 4    0.68 -0.875169   8.13
# ..    ...       ...    ...
# 445  0.97 -0.816767   9.91
# 446  0.74 -0.863086   8.30
# 447  0.91 -0.828850   9.40
# 448  0.78 -0.855030   8.71
# 449  0.89 -0.832878   9.11
#
# [450 rows x 3 columns]

# %%
Comp['avl']=b_predict

# %%
Comp
# Out:
#         A       avl
# 0    0.64 -0.883225
# 1    0.85 -0.840933
# 2    0.80 -0.851003
# 3    0.91 -0.828850
# 4    0.68 -0.875169
# ..    ...       ...
# 445  0.97 -0.816767
# 446  0.74 -0.863086
# 447  0.91 -0.828850
# 448  0.78 -0.855030
# 449  0.89 -0.832878
#
# [450 rows x 2 columns]
